# %% [markdown]
# <a href="https://colab.research.google.com/github/Sui8/Colab-Test/blob/main/colab_to_github_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
print(1 + 1)
# Out:
# Hello World!
# 2
